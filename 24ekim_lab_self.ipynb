# %% [markdown]
# <a href="https://colab.research.google.com/github/627alyosa451/hu-bby261-2025/blob/main/24ekim_lab_self.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV dosyasını oku
veriSeti = pd.read_csv("veriler.csv")

# Ülke seçimi için input al
ulke = "United Kingdom"

# Seçilen ülkenin verilerini filtrele
ulkeVerisi = veriSeti[veriSeti["Entity"] == ulke]

# Yıl ve abone sayısı verilerini al
yillar = ulkeVerisi["Year"]
aboneSayilari = ulkeVerisi["Fixed broadband subscriptions (per 100 people)"]

# Grafiği oluştur
plt.plot(yillar, aboneSayilari, marker="o")
plt.title(f"{ulke} İnternet Kullanımı (Yıllara Göre)")
plt.xlabel("Yıl")
plt.ylabel("Sabit Abonelik Sayıları")
plt.grid(True)
plt.xlim(2000, 2019)
plt.ylim(0, 100)
plt.show()
